# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
with open ("c:/Git/financial_sector_integrity/Data/FRB_H8_2000_2023.csv") as fp:
    df = pd.read_csv(fp)
    print(df.head())
# Out:
#     Series Description Bank credit, all commercial banks, seasonally adjusted  \
# 0                Unit:                                           Currency
# 1          Multiplier:                                            1000000
# 2            Currency:                                                USD
# 3  Unique Identifier:                                     H8/H8/B1001NCBA
# 4          Time Period                                          B1001NCBA
#
#   Securities in bank credit, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1002NCBA
# 4                                          B1002NCBA
#
#   Treasury and agency securities, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1003NCBA
# 4                                          B1003NCBA
#
#   Treasury and agency securities: Mortgage-backed securities (MBS), all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1301NCBA
# 4                                          B1301NCBA
#
#   Treasury and agency securities: Non-MBS, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1302NCBA
# 4                                          B1302NCBA
#
#   Other securities, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1011NCBA
# 4                                          B1011NCBA
#
#   Other securities: Mortgage-backed securities, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1303NCBA
# 4                                          B1303NCBA
#
#   Other securities: Non-MBS, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1304NCBA
# 4                                          B1304NCBA
#
#   Loans and leases in bank credit, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1020NCBA
# 4                                          B1020NCBA
#
#    ... Other assets, all commercial banks, seasonally adjusted  \
# 0  ...                                           Currency
# 1  ...                                            1000000
# 2  ...                                                USD
# 3  ...                                    H8/H8/B3053NCBA
# 4  ...                                          B3053NCBA
#
#   Total assets, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1151NCBA
# 4                                          B1151NCBA
#
#   Deposits, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1058NCBA
# 4                                          B1058NCBA
#
#   Large time deposits, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1072NCBA
# 4                                          B1072NCBA
#
#   Other deposits, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1110NCBA
# 4                                          B1110NCBA
#
#   Borrowings, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B3094NCBA
# 4                                          B3094NCBA
#
#   Net due to related foreign offices, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1100NCBA
# 4                                          B1100NCBA
#
#   Other liabilities, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B3095NCBA
# 4                                          B3095NCBA
#
#   Total liabilities, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1152NCBA
# 4                                          B1152NCBA
#
#   Residual (assets less liabilities), all commercial banks, seasonally adjusted
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1091NCBA
# 4                                          B1091NCBA
#
# [5 rows x 42 columns]

# %%
df.head()
# Out:
#     Series Description Bank credit, all commercial banks, seasonally adjusted  \
# 0                Unit:                                           Currency
# 1          Multiplier:                                            1000000
# 2            Currency:                                                USD
# 3  Unique Identifier:                                     H8/H8/B1001NCBA
# 4          Time Period                                          B1001NCBA
#
#   Securities in bank credit, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1002NCBA
# 4                                          B1002NCBA
#
#   Treasury and agency securities, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1003NCBA
# 4                                          B1003NCBA
#
#   Treasury and agency securities: Mortgage-backed securities (MBS), all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1301NCBA
# 4                                          B1301NCBA
#
#   Treasury and agency securities: Non-MBS, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1302NCBA
# 4                                          B1302NCBA
#
#   Other securities, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1011NCBA
# 4                                          B1011NCBA
#
#   Other securities: Mortgage-backed securities, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1303NCBA
# 4                                          B1303NCBA
#
#   Other securities: Non-MBS, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1304NCBA
# 4                                          B1304NCBA
#
#   Loans and leases in bank credit, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1020NCBA
# 4                                          B1020NCBA
#
#    ... Other assets, all commercial banks, seasonally adjusted  \
# 0  ...                                           Currency
# 1  ...                                            1000000
# 2  ...                                                USD
# 3  ...                                    H8/H8/B3053NCBA
# 4  ...                                          B3053NCBA
#
#   Total assets, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1151NCBA
# 4                                          B1151NCBA
#
#   Deposits, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1058NCBA
# 4                                          B1058NCBA
#
#   Large time deposits, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1072NCBA
# 4                                          B1072NCBA
#
#   Other deposits, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1110NCBA
# 4                                          B1110NCBA
#
#   Borrowings, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B3094NCBA
# 4                                          B3094NCBA
#
#   Net due to related foreign offices, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1100NCBA
# 4                                          B1100NCBA
#
#   Other liabilities, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B3095NCBA
# 4                                          B3095NCBA
#
#   Total liabilities, all commercial banks, seasonally adjusted  \
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1152NCBA
# 4                                          B1152NCBA
#
#   Residual (assets less liabilities), all commercial banks, seasonally adjusted
# 0                                           Currency
# 1                                            1000000
# 2                                                USD
# 3                                    H8/H8/B1091NCBA
# 4                                          B1091NCBA
#
# [5 rows x 42 columns]

# %%
df = df.set_index('Descriptions:').transpose()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 dft = df.set_index('Descriptions:').transpose()
#
# File c:\Users\Leo Salinas Chacon\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\Leo Salinas Chacon\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:6012, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6009                 missing.append(col)
#    6011 if missing:
# -> 6012     raise KeyError(f"None of {missing} are in the columns")
#    6014 if inplace:
#    6015     frame = self
#
# KeyError: "None of ['Descriptions:'] are in the columns"

# %%
dft['row_number'] = dft.reset_index().index
dft.head()
# Out:
# Descriptions:      Bank credit, all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1001NCBD
# Series Name:                                                B1001NCBD
#
# Descriptions:      Securities in bank credit, all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1002NCBD
# Series Name:                                                B1002NCBD
#
# Descriptions:      Treasury and agency securities, all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1003NCBD
# Series Name:                                                B1003NCBD
#
# Descriptions:      Treasury and agency securities: Mortgage-backed securities (MBS), all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1301NCBD
# Series Name:                                                B1301NCBD
#
# Descriptions:      Treasury and agency securities: Non-MBS, all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1302NCBD
# Series Name:                                                B1302NCBD
#
# Descriptions:      Other securities, all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1011NCBD
# Series Name:                                                B1011NCBD
#
# Descriptions:      Other securities: Mortgage-backed securities, all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1303NCBD
# Series Name:                                                B1303NCBD
#
# Descriptions:      Other securities: Non-MBS, all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1304NCBD
# Series Name:                                                B1304NCBD
#
# Descriptions:      Loans and leases in bank credit, all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1020NCBD
# Series Name:                                                B1020NCBD
#
# Descriptions:      Commercial and industrial loans, all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1023NCBD
# Series Name:                                                B1023NCBD
#
# Descriptions:       ...  \
# Unit:               ...
# Multiplier:         ...
# Currency:           ...
# Unique Identifier:  ...
# Series Name:        ...
#
# Descriptions:      Total assets, all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1151NCBD
# Series Name:                                                B1151NCBD
#
# Descriptions:      Deposits, all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1058NCBD
# Series Name:                                                B1058NCBD
#
# Descriptions:      Large time deposits, all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1072NCBD
# Series Name:                                                B1072NCBD
#
# Descriptions:      Other deposits, all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1110NCBD
# Series Name:                                                B1110NCBD
#
# Descriptions:      Borrowings, all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B3094NCBD
# Series Name:                                                B3094NCBD
#
# Descriptions:      Net due to related foreign offices, all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1100NCBD
# Series Name:                                                B1100NCBD
#
# Descriptions:      Other liabilities, all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B3095NCBD
# Series Name:                                                B3095NCBD
#
# Descriptions:      Total liabilities, all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1152NCBD
# Series Name:                                                B1152NCBD
#
# Descriptions:      Residual (assets less liabilities), all commercial banks, not seasonally adjusted  \
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1091NCBD
# Series Name:                                                B1091NCBD
#
# Descriptions:      row_number
# Unit:                       0
# Multiplier:                 1
# Currency:                   2
# Unique Identifier:          3
# Series Name:                4
#
# [5 rows x 42 columns]

# %%
df.drop(index=df.index[0:6], axis=0, inplace=True)

# %%
df.head()
# Out:
#    Series Description Bank credit, all commercial banks, seasonally adjusted  \
# 6          2000-01-12                                          4529676.8
# 7          2000-01-19                                          4543358.5
# 8          2000-01-26                                          4552980.6
# 9          2000-02-02                                          4551471.6
# 10         2000-02-09                                          4546483.8
#
#    Securities in bank credit, all commercial banks, seasonally adjusted  \
# 6                                           1148946.4
# 7                                           1147284.3
# 8                                           1153399.8
# 9                                           1143274.9
# 10                                          1139264.1
#
#    Treasury and agency securities, all commercial banks, seasonally adjusted  \
# 6                                            817136.2
# 7                                            815857.8
# 8                                            823303.3
# 9                                            821834.4
# 10                                           816719.4
#
#    Treasury and agency securities: Mortgage-backed securities (MBS), all commercial banks, seasonally adjusted  \
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#    Treasury and agency securities: Non-MBS, all commercial banks, seasonally adjusted  \
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#    Other securities, all commercial banks, seasonally adjusted  \
# 6                                            331810.2
# 7                                            331426.5
# 8                                            330096.5
# 9                                            321440.6
# 10                                           322544.7
#
#    Other securities: Mortgage-backed securities, all commercial banks, seasonally adjusted  \
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#    Other securities: Non-MBS, all commercial banks, seasonally adjusted  \
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#    Loans and leases in bank credit, all commercial banks, seasonally adjusted  \
# 6                                           3380730.4
# 7                                           3396074.3
# 8                                           3399580.7
# 9                                           3408196.7
# 10                                          3407219.7
#
#     ... Other assets, all commercial banks, seasonally adjusted  \
# 6   ...                                           471199.9
# 7   ...                                           475845.3
# 8   ...                                           474807.1
# 9   ...                                           487949.4
# 10  ...                                           486683.9
#
#    Total assets, all commercial banks, seasonally adjusted  \
# 6                                           5584100.3
# 7                                           5585805.9
# 8                                           5603887.2
# 9                                           5606724.5
# 10                                          5618559.1
#
#    Deposits, all commercial banks, seasonally adjusted  \
# 6                                           3472938.2
# 7                                           3488688.9
# 8                                           3489573.4
# 9                                           3488972.4
# 10                                          3491467.2
#
#    Large time deposits, all commercial banks, seasonally adjusted  \
# 6                                            840262.7
# 7                                            836411.3
# 8                                            837762.5
# 9                                            838679.9
# 10                                           834907.4
#
#    Other deposits, all commercial banks, seasonally adjusted  \
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#    Borrowings, all commercial banks, seasonally adjusted  \
# 6                                           1381594.9
# 7                                           1352571.7
# 8                                           1355312.3
# 9                                           1362224.2
# 10                                          1359818.1
#
#    Net due to related foreign offices, all commercial banks, seasonally adjusted  \
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#    Other liabilities, all commercial banks, seasonally adjusted  \
# 6                                            377146.3
# 7                                            379300.5
# 8                                            383449.9
# 9                                            395992.6
# 10                                           393125.7
#
#    Total liabilities, all commercial banks, seasonally adjusted  \
# 6                                           5367997.0
# 7                                           5359310.7
# 8                                           5374094.8
# 9                                           5387620.5
# 10                                          5405167.0
#
#    Residual (assets less liabilities), all commercial banks, seasonally adjusted
# 6                                            216103.3
# 7                                            226495.2
# 8                                            229792.4
# 9                                            219104.0
# 10                                           213392.1
#
# [5 rows x 42 columns]

# %%
df["Residual (assets less liabilities), all commercial banks, seasonally adjusted"]
df["Residual (assets less liabilities), all commercial banks, seasonally adjusted"]
# Out:
# str

# %%
df['Residual (assets less liabilities), all commercial banks, seasonally adjusted'] = df['Residual (assets less liabilities), all commercial banks, seasonally adjusted'].astype(float)

df['Series Description'] = pd.to_datetime(df['Series Description'])

# %%
df.shape

x = 'Series Description'

# y axis values
y = 'Residual_SA'

data_display =  pd.DataFrame({'Series_Description':df['Series Description'],'Residual_SA':df['Residual (assets less liabilities), all commercial banks, seasonally adjusted']})
# plotting strip plot with seaborn
sns.scatterplot(x='Series_Description', y='Residual_SA', data=data_display)
# Out:
# <Axes: xlabel='Series_Description', ylabel='Residual_SA'>

# %%
df['Deposits, all commercial banks, seasonally adjusted'] = df['Deposits, all commercial banks, seasonally adjusted'].astype(float)

# %%
x = 'Series Description'

# y axis values
y = 'Deposits_SA'

Deposits_time =  pd.DataFrame({'Series_Description':df['Series Description'],'Deposits_SA':df['Deposits, all commercial banks, seasonally adjusted']})
# plotting strip plot with seaborn
sns.scatterplot(x='Series_Description', y='Deposits_SA', data=Deposits_time)
# Out:
# <Axes: xlabel='Series_Description', ylabel='Deposits_SA'>

# %%
df['Total liabilities, all commercial banks, seasonally adjusted'] = df['Total liabilities, all commercial banks, seasonally adjusted'].astype(float)

# %%
x = 'Series Description'

# y axis values
y = 'T_Liabilities_SA'

Liabilities_time =  pd.DataFrame({'Series_Description':df['Series Description'],'T_Liabilities_SA':df['Total liabilities, all commercial banks, seasonally adjusted']})
# plotting strip plot with seaborn
sns.scatterplot(x='Series_Description', y='T_Liabilities_SA', data=Liabilities_time)
# Out:
# <Axes: xlabel='Series_Description', ylabel='T_Liabilities_SA'>

# %%
import seaborn as sns
import pandas as pd

# create sample data
data = pd.DataFrame({
    'x': [1, 2, 3, 4, 5],
    'y': [2, 4, 1, 5, 3]
})

# create a scatter plot
sns.scatterplot(x='x', y='y', data=data)
# Out:
# <Axes: xlabel='x', ylabel='y'>
