# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')
pd.options.display.max_rows = 200

# %%
with open ("c:/Git/financial_sector_integrity/Data/FRB_H8_20.csv") as fp3:
    df3 = pd.read_csv(fp3, header=1)
    print(df3.head())
# Out:
#   Bank credit, all commercial banks, not seasonally adjusted  Currency  \
# 0  Securities in bank credit, all commercial bank...          Currency
# 1  Treasury and agency securities, all commercial...          Currency
# 2  Treasury and agency securities: Mortgage-backe...          Currency
# 3  Treasury and agency securities: Non-MBS, all c...          Currency
# 4  Other securities, all commercial banks, not se...          Currency
#
#    1000000  USD  H8/H8/B1001NCBD  B1001NCBD  17304161.0  17332055.0  \
# 0  1000000  USD  H8/H8/B1002NCBD  B1002NCBD   5547014.0   5546651.0
# 1  1000000  USD  H8/H8/B1003NCBD  B1003NCBD   4461805.0   4464279.0
# 2  1000000  USD  H8/H8/B1301NCBD  B1301NCBD   2787640.0   2785681.0
# 3  1000000  USD  H8/H8/B1302NCBD  B1302NCBD   1674165.0   1678598.0
# 4  1000000  USD  H8/H8/B1011NCBD  B1011NCBD   1085209.0   1082372.0
#
#    17382012.0  17376849.0  ...  17595585.0  17571103.0  17534653.0  \
# ...

# %%
df3t = df3.transpose()
print(df3t.head())
# Out:
#                                                                                                    0   \
# Bank credit, all commercial banks, not seasonal...  Securities in bank credit, all commercial bank...
# Currency                                                                                     Currency
# 1000000                                                                                       1000000
# USD                                                                                               USD
# H8/H8/B1001NCBD                                                                       H8/H8/B1002NCBD
#
#                                                                                                    1   \
# Bank credit, all commercial banks, not seasonal...  Treasury and agency securities, all commercial...
# Currency                                                                                     Currency
# ...

# %%
#looking at the charateristics of the data to see what i can remove
print(df3t.shape)
print(df3t.isnull().any()) 
sns.heatmap(df3t.isnull(), yticklabels=False,)
plt.show()
# Out:
# (21, 41)
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# dtype: bool

# %%
#no null values ! lit
df3t.head()
# Out:
#                                                                    0   \
# Descriptions:       Bank credit, all commercial banks, not seasona...
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1001NCBD
#
#                                                                    1   \
# Descriptions:       Securities in bank credit, all commercial bank...
# Unit:                                                        Currency
# Multiplier:                                                   1000000
# Currency:                                                         USD
# Unique Identifier:                                    H8/H8/B1002NCBD
#
#                                                                    2   \
# ...

# %%
df3t.drop(index=df3t.index[1:6], axis=0, inplace=True)
df3t.drop(index=df3t.index[1],axis=1 )
# Out:
#                                                               0   \
# Descriptions:  Bank credit, all commercial banks, not seasona...
# 2022-10-26                                            17332055.0
# 2022-11-02                                            17382012.0
# 2022-11-09                                            17376849.0
# 2022-11-16                                            17407792.0
# 2022-11-23                                            17435851.0
# 2022-11-30                                            17481264.0
# 2022-12-07                                            17560037.0
# 2022-12-14                                            17569065.0
# 2022-12-21                                            17588887.0
# 2022-12-28                                            17595585.0
# 2023-01-04                                            17571103.0
# 2023-01-11                                            17534653.0
# ...

# %%
df3t.head()
# Out:
#                                                               0   \
# Descriptions:  Bank credit, all commercial banks, not seasona...
# 2022-10-19                                            17304161.0
# 2022-10-26                                            17332055.0
# 2022-11-02                                            17382012.0
# 2022-11-09                                            17376849.0
#
#                                                               1   \
# Descriptions:  Securities in bank credit, all commercial bank...
# 2022-10-19                                             5547014.0
# 2022-10-26                                             5546651.0
# 2022-11-02                                             5544194.0
# 2022-11-09                                             5536640.0
#
#                                                               2   \
# Descriptions:  Treasury and agency securities, all commercial...
# ...

# %%
\
# Out:
#                     0          1          2          3          4          5   \
# 2022-10-19  17304161.0  5547014.0  4461805.0  2787640.0  1674165.0  1085209.0
# 2022-10-26  17332055.0  5546651.0  4464279.0  2785681.0  1678598.0  1082372.0
# 2022-11-02  17382012.0  5544194.0  4465623.0  2783359.0  1682264.0  1078571.0
# 2022-11-09  17376849.0  5536640.0  4459077.0  2772894.0  1686183.0  1077563.0
# 2022-11-16  17407792.0  5552271.0  4469985.0  2780352.0  1689633.0  1082286.0
#
#                   6         7           8          9   ...         31  \
# 2022-10-19  112937.0  972272.0  11757147.0  2749527.0  ...  1858005.0
# 2022-10-26  112088.0  970284.0  11785404.0  2752016.0  ...  1854644.0
# 2022-11-02  112600.0  965971.0  11837818.0  2773721.0  ...  1870398.0
# 2022-11-09  112334.0  965229.0  11840209.0  2779109.0  ...  1894428.0
# 2022-11-16  112710.0  969576.0  11855521.0  2782975.0  ...  1881956.0
#
#                     32          33         34          35         36  \
# ...

# %%
pd.to_datetime(df3t['Descriptions'], axis=2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 pd.to_datetime(df3t['Descriptions'], axis=2)
#
# File c:\Users\Leo Salinas Chacon\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File c:\Users\Leo Salinas Chacon\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\range.py:395, in RangeIndex.get_loc(self, key, method, tolerance)
#     393             raise KeyError(key) from err
#     394     self._check_indexing_error(key)
# --> 395     raise KeyError(key)
#     396 return super().get_loc(key, method=method, tolerance=tolerance)
#
# ...

# %%
df3t_dates.head(42)
# Out:
#                                         Descriptions:  2022-10-19  2022-10-26  \
# 0   Bank credit, all commercial banks, not seasona...  17304161.0  17332055.0
# 1   Securities in bank credit, all commercial bank...   5547014.0   5546651.0
# 2   Treasury and agency securities, all commercial...   4461805.0   4464279.0
# 3   Treasury and agency securities: Mortgage-backe...   2787640.0   2785681.0
# 4   Treasury and agency securities: Non-MBS, all c...   1674165.0   1678598.0
# 5   Other securities, all commercial banks, not se...   1085209.0   1082372.0
# 6   Other securities: Mortgage-backed securities, ...    112937.0    112088.0
# 7   Other securities: Non-MBS, all commercial bank...    972272.0    970284.0
# 8   Loans and leases in bank credit, all commercia...  11757147.0  11785404.0
# 9   Commercial and industrial loans, all commercia...   2749527.0   2752016.0
# 10  Real estate loans, all commercial banks, not s...   5210937.0   5223398.0
# ...
